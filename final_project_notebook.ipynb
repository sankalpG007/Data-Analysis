# %% [markdown]
# # Data Science Ecosystems: A Final Project Notebook

# %% [markdown]
# ## Introduction
# This notebook serves as the final project for the Coursera course, demonstrating familiarity with fundamental concepts, languages, libraries, and tools in the field of Data Science.

# %% [markdown]
# ## Data Science Languages
#
# Some of the most popular languages used by Data Scientists include:
#
# 1. Python
# 2. R
# 3. SQL
# 4. Scala
# 5. Julia

# %% [markdown]
# ## Data Science Libraries
#
# Key libraries that are essential for Data Science tasks include:
#
# **For Python:**
#
# 1. Pandas (data manipulation and analysis)
# 2. NumPy (numerical operations)
# 3. Matplotlib (data visualization)
# 4. Scikit-learn (machine learning)
# 5. TensorFlow / PyTorch (deep learning)
#
# **For R:**
#
# 6. ggplot2 (data visualization)
# 7. dplyr (data manipulation)

# %% [markdown]
# ## Data Science Tools
#
# | Category | Tool |
# |:---|:---|
# | **Development Environments** | Jupyter Notebook/Lab, RStudio, VS Code |
# | **Data Management** | MySQL, PostgreSQL, Apache Hadoop |
# | **Visualization Tools** | Tableau, Power BI, D3.js |
# | **Version Control** | Git, GitHub |

# %% [markdown]
# ## Introducing Arithmetic Expression Examples
#
# In the following code cells, we will perform some basic arithmetic operations, such as multiplication and addition, and demonstrate a simple unit conversion.

# %%
# This is a simple arithmetic expression to multiply then add integers
result = (3 * 4) + 5
print(f"The result of (3 * 4) + 5 is: {result}")

# %%
# This code cell will convert 200 minutes to hours by dividing by 60
minutes = 200
hours = minutes / 60

print(f"{minutes} minutes is equal to {hours} hours")

# %% [markdown]
# ## Objectives
#
# The main objectives of this final project notebook are to:
#
# * Demonstrate proficiency in creating and formatting Markdown cells.
# * Show an understanding of key Data Science languages and libraries.
# * Illustrate basic arithmetic operations using Python code cells.
# * Successfully use the Jupyter environment for creating and sharing a project.

# %% [markdown]
# ## Author
#
# **[Insert Your Full Name Here]**
#
# *This project was completed as the final assignment for the "Tools for Data Science" course on Coursera.*
